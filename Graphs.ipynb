# %% [markdown]
# <a href="https://colab.research.google.com/github/heshu-000/python/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([5,8])
ypoints = np.array([3,7])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["football", "vollyball", "basketball", "cricket"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 5, 6, 9])
ypoints = np.array([5, 6, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([40, 5, 35, 20])
a=['maths','phy','che','cse']
plt.pie(y,labels=a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,17,2,9,4,11,12,9,6])
y = np.array([44,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(70, 10, 250)

plt.hist(x)
plt.show()
